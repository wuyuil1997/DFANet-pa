# %%
#数据路径设置
import os
import sys
os.environ['CUDA_VISIBLE_DEVICES'] = '0'

import numpy as np
import cv2
import matplotlib.pyplot as plt
DATA_DIR = '..\camvid' # 根据自己的路径来设置

x_train_dir = os.path.join(DATA_DIR, 'train_images')
y_train_dir = os.path.join(DATA_DIR, 'train_labels')

x_valid_dir = os.path.join(DATA_DIR, 'valid_images')
y_valid_dir = os.path.join(DATA_DIR, 'valid_labels')

x_test_dir = os.path.join(DATA_DIR, 'test_images')
y_test_dir = os.path.join(DATA_DIR, 'test_labels')

print(x_train_dir, y_train_dir, x_valid_dir, y_valid_dir, x_test_dir, y_test_dir)
# Out:
# ..\camvid\train_images ..\camvid\train_labels ..\camvid\valid_images ..\camvid\valid_labels ..\camvid\test_images ..\camvid\test_labels

# %%
#数据加载类，用于训练、验证、测试时提供数据加载支持
import torch
import random
from torch.utils.data import DataLoader
from torch.utils.data import Dataset as BaseDataset

class Dataset(BaseDataset):
    """CamVid Dataset. Read images, apply augmentation and preprocessing transformations.
    
    Args:
        images_dir (str): path to images folder
        masks_dir (str): path to segmentation masks folder
        class_values (list): values of classes to extract from segmentation mask
        augmentation (albumentations.Compose): data transfromation pipeline 
            (e.g. flip, scale, etc.)
        preprocessing (albumentations.Compose): data preprocessing 
            (e.g. noralization, shape manipulation, etc.)
    
    """
    CLASSES = ['animal', 'archway', 'bicyclist', 'bridge', 'building', 'car', 'cartluggagepram',
               'child', 'column_pole', 'fence', 'lanemkgsdriv', 'lanemkgsnondriv',
               'misc_text', 'motorcyclescooter', 'othermoving', 'parkingblock', 'pedestrian',
               'road', 'roadshoulder', 'sidewalk', 'signsymbol', 'sky', 'suvpickuptruck',
               'trafficcone', 'trafficlight', 'train', 'tree', 'truck_bus', 'tunnel', 'vegetationmisc', 
               'void', 'wall']
    def __init__(
            self, 
            images_dir, 
            masks_dir, 
            classes=None,
            augmentation=None,
    ):
        self.ids = os.listdir(images_dir)
        self.images_fps = [os.path.join(images_dir, image_id) for image_id in self.ids]
        self.masks_fps = [os.path.join(masks_dir, image_id) for image_id in self.ids]
        self.class_values = [self.CLASSES.index(cls.lower()) for cls in classes]
        '''for content in self.class_values:
            print('self.class_values:', content)'''
        
        self.augmentation = augmentation

    
    def __getitem__(self, i):
                
        # read data
        #print("ids: %d" % i)
        #由于anaconda会在各个目录添加.ipynb_check...的文件，当当前读取的文件名称不是png文件时,重新随机读取文件
        while self.images_fps[i][-4:] != '.png':
            #print('%s is not a png file!' % self.images_fps[i])
            i = random.randint(0,len(self.ids) - 1)
            #print('try to use file %s.' % self.images_fps[i])
        if self.images_fps[i].split('\\')[-1] != self.images_fps[i].split('\\')[-1]:
            print('error: label:%s is not match to images:%s' % (self.images_fps[i].split('\\')[-1], self.images_fps[i].split('\\')[-1]))
            os._exit() 
        #print(self.images_fps[i])
        #print(self.masks_fps[i])
        image = cv2.imread(self.images_fps[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        mask = cv2.imread(self.masks_fps[i], 0)
        
        #多分类
        masks = [(mask == v) for v in self.class_values]
        mask = np.stack(masks, axis=-1).astype('float')
        
        # add background if mask is not binary
        if mask.shape[-1] != 1:
            background = 1 - mask.sum(axis=-1, keepdims=True)
            mask = np.concatenate((mask, background), axis=-1)
        
        #为进行二分类，此处将label文件调整为只有road与背景的图片
        #mask = (mask==90)
        #mask = (mask==17)
        #mask = mask.astype('float')  
        #plt.imshow(mask)
        # apply augmentations
        if self.augmentation:
            sample = self.augmentation(image=image, mask=mask)
            image, mask = sample['image'], sample['mask']
        return image, mask
        #return image, mask.reshape(len(self.class_values) + 1, 360, 480)
        
    def __len__(self):
        return len(self.ids)

# %%
#### 定义图像增强函数以及图片展示函数
import albumentations as albu

def get_training_augmentation():
    train_transform = [
        albu.HorizontalFlip(p=0.5),
        albu.Resize(height=360, width=480, always_apply=True),
        albu.ShiftScaleRotate(scale_limit=0.1, rotate_limit=20, shift_limit=0.1, p=1, border_mode=0),
    ]
    return albu.Compose(train_transform)

def get_test_augmentation():
    train_transform = [
        albu.Resize(height=360, width=480, always_apply=True),
    ]
    return albu.Compose(train_transform)       

def get_val_augmentation():
    train_transform = [
        albu.Resize(height=360, width=480, always_apply=True),
    ]
    return albu.Compose(train_transform)  

augmented_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=['Road', 'building'],
    augmentation=get_training_augmentation(), 
)

def visualize(**images):
    """PLot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

# same image with different random transforms
for i in range(2):
    image, mask = augmented_dataset[16]
    print(np.min(image),np.max(image))
    print(len(augmented_dataset))
    print('imageshape:', image.shape, 'maskshape:', mask.shape)
    visualize(image=image, 
              road_mask=mask[..., 0].squeeze(),
              pedestrian_mask=mask[..., 1].squeeze(),
              background_mask=mask[..., 2].squeeze()
             )
# Out:
# 0 255
# 491
# imageshape: (360, 480, 3) maskshape: (360, 480, 3)
# 0 254
# 491
# imageshape: (360, 480, 3) maskshape: (360, 480, 3)

# %%
#构建训练、验证数据集
CLASSES = ['Road', 'Car', 'Building', 'sky', 'tree', 'sidewalk', 'Pedestrian']
train_dataset = Dataset(
    x_train_dir, 
    y_train_dir, 
    classes=CLASSES,
    augmentation=get_training_augmentation(), 
)

valid_dataset = Dataset(
    x_valid_dir, 
    y_valid_dir, 
    classes=CLASSES,
    augmentation=get_val_augmentation(), 
)

train_loader = DataLoader(train_dataset, batch_size=1, shuffle=True)
valid_loader = DataLoader(valid_dataset, batch_size=2, shuffle=False)

n_classes = 1 if len(CLASSES) == 1 else (len(CLASSES) + 1)

# %%
#DFANet模型搭建
import math
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.model_zoo as model_zoo

class FPA(nn.Module):
    def __init__(self, channels=2048):
        """
        Feature Pyramid Attention
        :type channels: int
        """
        super(FPA, self).__init__()
        channels_mid = int(channels/4)

        self.channels_cond = channels

        # Master branch
        self.conv_master = nn.Conv2d(self.channels_cond, channels, kernel_size=1, bias=False)
        self.bn_master = nn.BatchNorm2d(channels)

        # Global pooling branch
        self.conv_gpb = nn.Conv2d(self.channels_cond, channels, kernel_size=1, bias=False)
        self.bn_gpb = nn.BatchNorm2d(channels)

        # C333 because of the shape of last feature maps is (16, 16).
        self.conv7x7_1 = nn.Conv2d(self.channels_cond, channels_mid, kernel_size=(7, 7), stride=2, padding=3, bias=False)
        self.bn1_1 = nn.BatchNorm2d(channels_mid)
        self.conv5x5_1 = nn.Conv2d(channels_mid, channels_mid, kernel_size=(5, 5), stride=2, padding=2, bias=False)
        self.bn2_1 = nn.BatchNorm2d(channels_mid)
        self.conv3x3_1 = nn.Conv2d(channels_mid, channels_mid, kernel_size=(3, 3), stride=2, padding=1, bias=False)
        self.bn3_1 = nn.BatchNorm2d(channels_mid)

        self.conv7x7_2 = nn.Conv2d(channels_mid, channels_mid, kernel_size=(7, 7), stride=1, padding=3, bias=False)
        self.bn1_2 = nn.BatchNorm2d(channels_mid)
        self.conv5x5_2 = nn.Conv2d(channels_mid, channels_mid, kernel_size=(5, 5), stride=1, padding=2, bias=False)
        self.bn2_2 = nn.BatchNorm2d(channels_mid)
        self.conv3x3_2 = nn.Conv2d(channels_mid, channels_mid, kernel_size=(3, 3), stride=1, padding=1, bias=False)
        self.bn3_2 = nn.BatchNorm2d(channels_mid)

        # Convolution Upsample
        self.conv_upsample_3 = nn.ConvTranspose2d(channels_mid, channels_mid, kernel_size=4, stride=2, padding=1, bias=False)
        self.bn_upsample_3 = nn.BatchNorm2d(channels_mid)

        self.conv_upsample_2 = nn.ConvTranspose2d(channels_mid, channels_mid, kernel_size=4, stride=2, padding=1, bias=False)
        self.bn_upsample_2 = nn.BatchNorm2d(channels_mid)

        self.conv_upsample_1 = nn.ConvTranspose2d(channels_mid, channels, kernel_size=4, stride=2, padding=1, bias=False)
        self.bn_upsample_1 = nn.BatchNorm2d(channels)

        self.relu = nn.ReLU(inplace=True)
    
    def forward(self, x):
        """
        :param x: Shape: [b, 2048, h, w]
        :return: out: Feature maps. Shape: [b, 2048, h, w]
        """
        # Master branch
        x_master = self.conv_master(x)
        x_master = self.bn_master(x_master)

        # Global pooling branch
        x_gpb = nn.AvgPool2d(x.shape[2:])(x).view(x.shape[0], self.channels_cond, 1, 1)
        x_gpb = self.conv_gpb(x_gpb)
        x_gpb = self.bn_gpb(x_gpb)

        # Branch 1
        #print('x:',x.shape)
        x1_1 = self.conv7x7_1(x)
        #print('after con7x7 x:',x1_1.shape)
        x1_1 = self.bn1_1(x1_1)
        x1_1 = self.relu(x1_1)
        x1_2 = self.conv7x7_2(x1_1)
        x1_2 = self.bn1_2(x1_2)

        # Branch 2
        x2_1 = self.conv5x5_1(x1_1)
        x2_1 = self.bn2_1(x2_1)
        x2_1 = self.relu(x2_1)
        x2_2 = self.conv5x5_2(x2_1)
        x2_2 = self.bn2_2(x2_2)

        # Branch 3
        x3_1 = self.conv3x3_1(x2_1)
        x3_1 = self.bn3_1(x3_1)
        x3_1 = self.relu(x3_1)
        x3_2 = self.conv3x3_2(x3_1)
        x3_2 = self.bn3_2(x3_2)

        # Merge branch 1 and 2
        x3_upsample = self.relu(self.bn_upsample_3(self.conv_upsample_3(x3_2)))
        
        diffY = torch.tensor([x3_upsample.size()[2] - x2_2.size()[2]])
        diffX = torch.tensor([x3_upsample.size()[3] - x2_2.size()[3]])
        x2_2 = F.pad(x2_2, [diffX // 2, diffX - diffX // 2, 
                          diffY // 2, diffY - diffY // 2])
        
        x2_merge = self.relu(x2_2 + x3_upsample)
        
        x2_upsample = self.relu(self.bn_upsample_2(self.conv_upsample_2(x2_merge)))

        diffY = torch.tensor([x2_upsample.size()[2] - x1_2.size()[2]])
        diffX = torch.tensor([x2_upsample.size()[3] - x1_2.size()[3]])
 
        x1_2 = F.pad(x1_2, [diffX // 2, diffX - diffX // 2, 
                          diffY // 2, diffY - diffY // 2])
    
        #print('x1_2 + x2_upsample:', x1_2.shape, x2_upsample.shape)
        x1_merge = self.relu(x1_2 + x2_upsample)
        
        x1_upsample = self.relu(self.bn_upsample_1(self.conv_upsample_1(x1_merge)))
        
        diffY = torch.tensor([x1_upsample.size()[2] - x_master.size()[2]])
        diffX = torch.tensor([x1_upsample.size()[3] - x_master.size()[3]])
 
        x_master = F.pad(x_master, [diffX // 2, diffX - diffX // 2, 
                          diffY // 2, diffY - diffY // 2])

        x_master = x_master * x1_upsample

        out = self.relu(x_master + x_gpb)

        return out

#可分离卷积
class SeparableConv2d(nn.Module):
    def __init__(self, inputChannel, outputChannel, kernel_size=3, stride=1, padding=1, dilation=1, bias=True):
        super(SeparableConv2d, self).__init__()
        self.conv1 = nn.Conv2d(inputChannel, inputChannel, kernel_size, stride, padding, dilation,
                               groups=inputChannel, bias=bias)
        self.pointwise = nn.Conv2d(inputChannel, outputChannel, 1, 1, 0, 1, 1, bias=bias)
    def forward(self, x):
        x = self.conv1(x)
        x = self.pointwise(x)
        return x


# encoder block
class Block(nn.Module):
    """
    Base block for XceptionA and DFANet.
    inputChannel: channels of inputs of the base block.
    outputChannel:channnels of outputs of the base block.
    stride: stride
    BatchNorm:
    """
    def __init__(self, inputChannel, outputChannel,stride=1,BatchNorm=nn.BatchNorm2d):
        super(Block, self).__init__()

        self.conv1=nn.Sequential(SeparableConv2d(inputChannel,outputChannel//4,stride=stride,),
                                BatchNorm(outputChannel//4),
                                nn.ReLU())
        self.conv2=nn.Sequential(SeparableConv2d(outputChannel//4,outputChannel//4),
                                BatchNorm(outputChannel//4),
                                nn.ReLU())
        self.conv3=nn.Sequential(SeparableConv2d(outputChannel//4,outputChannel),
                                BatchNorm(outputChannel),
                                nn.ReLU())
        self.projection=nn.Conv2d(inputChannel,outputChannel,1,stride=stride,bias=False)
        
       
    def forward(self, x):
        out=self.conv1(x)
        out=self.conv2(out)
        out=self.conv3(out)
        identity=self.projection(x)
        return out+identity


class enc(nn.Module):
    """
    encoders:
    in_channels:The channels of input feature maps
    out_channnel:the channels of outputs of this enc.
    """
    def __init__(self,in_channels,out_channels,stride=2,num_repeat=3):
        super(enc, self).__init__()
        stacks=[Block(in_channels,out_channels,stride=2)]
        for x in range(num_repeat-1):
            stacks.append(Block(out_channels,out_channels))
        self.build=nn.Sequential(*stacks)
        # self.block1=Block(in_channels,out_channels,stride=2)
        # self.block2=Block(out_channels,out_channels)
        # self.block3=Block(out_channels,out_channels)
    def forward(self, x):
        x=self.build(x)
        # x=self.block2(x)
        # x=self.block3(x)
        return x

class Attention(nn.Module):
    """
    self attention model.
    """
    def __init__(self,in_channels,out_channels):
        super(Attention,self).__init__()
        self.avg_pool=nn.AdaptiveAvgPool2d(1)
        self.fc=nn.Sequential(
            nn.Linear(in_channels,1000,bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(1000, out_channels, bias=False),
            nn.Sigmoid()
        )

    def forward(self,x):
        b,c,_,_=x.size()
        y=self.avg_pool(x).view(b,c)
        y=self.fc(y).view(b,c,1,1)
        return x*y.expand_as(x)

        
class SubBranch(nn.Module):
    """
    channel_cfg: channels of the inputs of enc stage
    branch_index: 0,1,2,
    """
    def __init__(self,channel_cfg,branch_index):
        super(SubBranch,self).__init__()
        self.enc2=enc(channel_cfg[0],48,num_repeat=3)
        self.enc3=enc(channel_cfg[1],96,num_repeat=6)
        self.enc4=enc(channel_cfg[2],192,num_repeat=3)
        self.atten=Attention(192,192)
        #self.atten=FPA(192)
        self.branch_index=branch_index
    
    def forward(self,x0,*args):
        out0=self.enc2(x0)
        if self.branch_index in [1,2]:
            out1=self.enc3(torch.cat([out0,args[0]],1))
            out2=self.enc4(torch.cat([out1,args[1]],1))
        else:
            out1=self.enc3(out0)
            out2=self.enc4(out1)
        out3=self.atten(out2)
        return [out0,out1,out2,out3]    

class XceptionA(nn.Module):
    """
    channel_cfg:channels of inputs of enc block.
    n_classes:
    """
    def __init__(self,channel_cfg,n_classes):
        super(XceptionA, self).__init__()
        self.conv1=nn.Sequential(nn.Conv2d(in_channels=3,out_channels=8,kernel_size=3,stride=2,padding=1,bias=False),
                                nn.BatchNorm2d(num_features=8),
                                nn.ReLU())
        self.branch=SubBranch(channel_cfg,branch_index=0)
        self.avg_pool=nn.AdaptiveAvgPool2d(1)
    
        self.classifier=nn.Sequential(nn.Linear(192,1000),
                                      nn.ReLU(inplace=True),
                                      nn.Linear(1000,n_classes))
        for m in self.modules():
            weight_init(m)

    def forward(self,x):
        b,c,_,_=x.size()
        x=self.conv1(x)
        _,_,_,x=self.branch(x)
        x=self.avg_pool(x).view(b,-1)
        x=self.classifier(x)
        return x

class DFA_Encoder(nn.Module):
    """
    Encoder of DFANet.
    """
    def __init__(self,channel_cfg):
        super(DFA_Encoder,self).__init__()
        self.conv1=nn.Sequential(nn.Conv2d(in_channels=3,out_channels=8,kernel_size=3,stride=2,padding=1,bias=False),
                                nn.BatchNorm2d(num_features=8),
                                nn.ReLU())
        self.branch0=SubBranch(channel_cfg[0],branch_index=0)
        self.branch1=SubBranch(channel_cfg[1],branch_index=1)
        self.branch2=SubBranch(channel_cfg[2],branch_index=2)

    def forward(self,x):

        x=self.conv1(x)

        x0,x1,x2,x5=self.branch0(x)
        x3=F.interpolate(x5,x0.size()[2:],mode='bilinear',align_corners=True)
        x1,x2,x3,x6=self.branch1(torch.cat([x0,x3],1),x1,x2)
        x4=F.interpolate(x6,x1.size()[2:],mode='bilinear',align_corners=True)
        x2,x3,x4,x7=self.branch2(torch.cat([x1,x4],1),x2,x3)

        return [x0,x1,x2,x5,x6,x7]


class DFA_Decoder(nn.Module):
    """
        Decoder of DFANet.
    """
    def __init__(self,decode_channels,n_classes):
        super(DFA_Decoder,self).__init__()


        self.conv0=nn.Sequential(nn.Conv2d(in_channels=48,out_channels=decode_channels,kernel_size=1,bias=False),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))
        self.conv1=nn.Sequential(nn.Conv2d(in_channels=48,out_channels=decode_channels,kernel_size=1,bias=False),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))
        self.conv2=nn.Sequential(nn.Conv2d(in_channels=48,out_channels=decode_channels,kernel_size=1,bias=False),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))
        self.conv3=nn.Sequential(nn.Conv2d(in_channels=192,out_channels=decode_channels,kernel_size=1,bias=False),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))
        self.conv4=nn.Sequential(nn.Conv2d(in_channels=192,out_channels=decode_channels,kernel_size=1,bias=False),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))
        self.conv5=nn.Sequential(nn.Conv2d(in_channels=192,out_channels=decode_channels,kernel_size=1,bias=False),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))

        self.conv_add1=nn.Sequential(nn.Conv2d(in_channels=decode_channels,out_channels=decode_channels,kernel_size=3,padding=1),
                                 nn.BatchNorm2d(decode_channels),
                                 nn.ReLU(inplace=True))
                                

        self.conv_cls=nn.Conv2d(in_channels=decode_channels,out_channels=n_classes,kernel_size=3,padding=1,bias=False)

    def forward(self,x0,x1,x2,x3,x4,x5):

        x0=self.conv0(x0)
        x1=F.interpolate(self.conv1(x1),x0.size()[2:],mode='bilinear',align_corners=True)
        x2=F.interpolate(self.conv2(x2),x0.size()[2:],mode='bilinear',align_corners=True)
        x3=F.interpolate(self.conv3(x3),x0.size()[2:],mode='bilinear',align_corners=True)
        x4=F.interpolate(self.conv5(x4),x0.size()[2:],mode='bilinear',align_corners=True)
        x5=F.interpolate(self.conv5(x5),x0.size()[2:],mode='bilinear',align_corners=True)

        x_shallow=self.conv_add1(x0+x1+x2)

        x=self.conv_cls(x_shallow+x3+x4+x5)
        x=F.interpolate(x,scale_factor=4,mode='bilinear',align_corners=True)
        return x

class DFANet(nn.Module):
    def __init__(self,channel_cfg,decoder_channel,n_classes):
        super(DFANet,self).__init__()
        self.n_classes = n_classes
        self.encoder=DFA_Encoder(channel_cfg)
        self.decoder=DFA_Decoder(decoder_channel,n_classes)
        weight_init(self.encoder)
        weight_init(self.decoder)
    def forward(self,x):
        x0,x1,x2,x3,x4,x5=self.encoder(x)
        x=self.decoder(x0,x1,x2,x3,x4,x5)
        return x

def weight_init(module):
    #print('initialize  ',module._get_name())
    for n,m in module.named_children():
        if isinstance(m,nn.Conv2d):
            nn.init.kaiming_normal_(m.weight,mode='fan_in',nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m,(nn.BatchNorm2d,nn.InstanceNorm2d)):
            nn.init.ones_(m.weight)
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m,nn.Linear):
            nn.init.kaiming_normal_(m.weight,mode='fan_in',nonlinearity='relu')
            if m.bias is not None:
                nn.init.zeros_(m.bias)
        elif isinstance(m,(nn.Sequential,
                            SubBranch,
                            enc,Block,
                            SeparableConv2d,
                            Attention,
                            DFA_Encoder,
                            DFA_Decoder)):
            weight_init(m)
        elif isinstance(m,(nn.ReLU,nn.ReLU,nn.ReLU6)):
            pass
        else:
            pass

# %%
#DFANet模型测试以及预训练模型加载
import time
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

ch_cfg=[[8,48,96],
        [240,144,288],
        [240,144,288]]


input = torch.randn(2, 3, 180, 240)
input=input.to(device)

#decoder test
#input=input.to(device)
net=DFANet(ch_cfg,64,n_classes)
net=net.to(device)
net(input)
start=time.time()
outputs=net(input)
end=time.time()

print(outputs.size())
print("inference time",end-start)
print("test DFANet sucessfully...")
# Out:
# torch.Size([2, 8, 180, 240])
# inference time 0.13792061805725098
# test DFANet sucessfully...

# %%
#搭建DFANet模型
class Config(object):
    
    NAME= "dfaNet"

    #set the output every STEP_PER_EPOCH iteration
    STEP_PER_EPOCH = 100
    ENCODER_CHANNEL_CFG=ch_cfg=[[8,48,96],
                                [240,144,288],
                                [240,144,288]]
cfg = Config()
net = DFANet(cfg.ENCODER_CHANNEL_CFG,decoder_channel=64,n_classes=n_classes)

# %%
print(net)
# Out:
# DFANet(
#   (encoder): DFA_Encoder(
#     (conv1): Sequential(
#       (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU()
#     )
#     (branch0): SubBranch(
#       (enc2): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(8, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=8)
#                 (pointwise): Conv2d(8, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(8, 48, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (enc3): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 96, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (4): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (enc4): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 192, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#                 (pointwise): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#                 (pointwise): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (atten): Attention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=192, out_features=1000, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=1000, out_features=192, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (branch1): SubBranch(
#       (enc2): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240)
#                 (pointwise): Conv2d(240, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(240, 48, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (enc3): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144)
#                 (pointwise): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(144, 96, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (4): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (enc4): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288)
#                 (pointwise): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(288, 192, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#                 (pointwise): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#                 (pointwise): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (atten): Attention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=192, out_features=1000, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=1000, out_features=192, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (branch2): SubBranch(
#       (enc2): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240)
#                 (pointwise): Conv2d(240, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(240, 48, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 12, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=12)
#                 (pointwise): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (enc3): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144)
#                 (pointwise): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(144, 96, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (3): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (4): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (5): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=96)
#                 (pointwise): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24)
#                 (pointwise): Conv2d(24, 96, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(96, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (enc4): enc(
#         (build): Sequential(
#           (0): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288)
#                 (pointwise): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(288, 192, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           )
#           (1): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#                 (pointwise): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#           (2): Block(
#             (conv1): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192)
#                 (pointwise): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv2): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 48, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (conv3): Sequential(
#               (0): SeparableConv2d(
#                 (conv1): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48)
#                 (pointwise): Conv2d(48, 192, kernel_size=(1, 1), stride=(1, 1))
#               )
#               (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (2): ReLU()
#             )
#             (projection): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           )
#         )
#       )
#       (atten): Attention(
#         (avg_pool): AdaptiveAvgPool2d(output_size=1)
#         (fc): Sequential(
#           (0): Linear(in_features=192, out_features=1000, bias=False)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=1000, out_features=192, bias=False)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (decoder): DFA_Decoder(
#     (conv0): Sequential(
#       (0): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv1): Sequential(
#       (0): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv2): Sequential(
#       (0): Conv2d(48, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv3): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv4): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv5): Sequential(
#       (0): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv_add1): Sequential(
#       (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU(inplace=True)
#     )
#     (conv_cls): Conv2d(64, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   )
# )

# %%
#数据集类别提取以及展示
image, mask = train_dataset[1]
net.eval()
with torch.no_grad():
    net.to('cuda')
    image = image/255.
    image = image.astype('float32')
    image = torch.from_numpy(image)
    image = image.permute(2,0,1)
    image = image.to()
    
    pred = net(image.unsqueeze(0).cuda())
    pred = pred.cpu()
for cnt in range(len(CLASSES)):
    print(CLASSES[cnt])
    plt.figure('mask')
    #print('mask.shape', mask.shape)
    #print('mask:', mask[..., 0])
    print(np.min(mask),np.max(mask))
    #plt.imshow(mask[0,:,:])
    plt.imshow(mask[..., cnt].squeeze())
    plt.show()

plt.figure('pred')
#pred = pred > 0.5
print('pred.shape:', pred.shape)
print(np.min(pred.numpy()),np.max(pred.numpy()))
plt.imshow(pred[0,0,:,:])
plt.show()
# Out:
# Road
# 0.0 1.0
# Car
# 0.0 1.0
# Building
# 0.0 1.0
# sky
# 0.0 1.0
# tree
# 0.0 1.0
# sidewalk
# 0.0 1.0
# Pedestrian
# 0.0 1.0
# pred.shape: torch.Size([1, 8, 360, 480])
# -2170156500000.0 4221179000000.0

# %%
#对预测结果进行mIoU计算
import torch
import numpy as np
def Iou(input,target,classNum):
    '''
    :param input: [b,h,w]
    :param target: [b,h,w]
    :param classNum: scalar
    :return:
    '''
    inputTmp = torch.zeros([input.shape[0],classNum,input.shape[1],input.shape[2]])#创建[b,c,h,w]大小的0矩阵
    targetTmp = torch.zeros([target.shape[0],classNum,target.shape[1],target.shape[2]])#同上
    input = input.unsqueeze(1)#将input维度扩充为[b,1,h,w]
    target = target.unsqueeze(1)#同上
    
    inputOht = inputTmp.scatter_(index=input,dim=1,value=1)#input作为索引，将0矩阵转换为onehot矩阵
    targetOht = targetTmp.scatter_(index=target,dim=1,value=1)#同上
    batchMious = []#为该batch中每张图像存储一个miou
    total_miou = 0.
    #print('in iou \n inputOht:', inputOht.shape, '\n targetOht:', targetOht.shape)
    mul = inputOht * targetOht#乘法计算后，其中1的个数为intersection
    for i in range(input.shape[0]):#遍历图像
        ious = []
        for j in range(classNum):#遍历类别，包括背景
            intersection = torch.sum(mul[i][j])
            union = torch.sum(inputOht[i][j]) + torch.sum(targetOht[i][j]) - intersection + 1e-6
            iou = intersection / union
            ious.append(iou)
        miou = np.mean(ious)#计算该图像的miou
        #batchMious.append(miou)
        total_miou += miou
    return total_miou / input.shape[0]

# %%
#评估模型在验证集上的mIoU
import torch
import torch.nn.functional as F
#from tqdm import tqdm


def eval_net(net, loader, device):
    """return mIoU in the module of valid_data """
    net.eval()
    mask_type = torch.float32 if net.n_classes == 1 else torch.long
    #mask_type = torch.float32
    n_val = len(loader)  # the number of batch
    tot = 0
    mIoU = 0
    cnt = 0

    for image, label in loader:
        with torch.no_grad():
            image = image.permute(0,3,1,2)
            image = image.to(device=device, dtype=torch.float32)
            image = image/255
            mask = label.to(device=device, dtype=mask_type)
            #print('image:', image.shape, '\n', image)
            
            pred = net(image)
        #print('pred.shape:', pred.shape, pred)
        if net.n_classes > 1:
            mask = torch.topk(mask, 1)[1].squeeze(1)
            #print('in eval \n  mask:',mask.shape, mask)
            mask = mask[..., 0].cpu()
            
            pred = pred.permute(0, 2, 3, 1)
            pred = torch.topk(pred, 1)[1].squeeze(1)
            #print('in eval \n  pred:',pred.shape, pred)
            pred = pred[..., 0].cpu()
            #pred = pred.permute(2, 0, 1).cpu()
            
            miou = Iou(mask, pred, net.n_classes)
            cnt += 1
            print('cnt: %d miou : %f' % (cnt, miou), end='\r')
            sys.stdout.flush()
            tot += miou
        else:
            pred = torch.sigmoid(mask_pred)
            pred = (pred > 0.5).float()
            tot += dice_coeff(pred, true_masks).item()
    return tot / cnt

# %%
#在验证集上进行loss计算
def eval_val_loss(net, loader, device):
    criterion = nn.CrossEntropyLoss()
    net.eval()
    mask_type = torch.float32 if net.n_classes == 1 else torch.long
    #mask_type = torch.float32
    n_val = len(loader)  # the number of batch
    tot = 0.
    cnt = 0
    
    for data in loader:
        with torch.no_grad():
            images,labels = data
            images = images.permute(0, 3, 1, 2)
            images = Variable(images.to(device=device, dtype=torch.float32))
            images = images/255.
            mask_type = torch.float32 if net.n_classes == 1 else torch.long
            labels = Variable(labels.to(device=device, dtype=mask_type))
            pred = net(images)
            
            labels = torch.topk(labels, 1)[1].squeeze(1)
            labels = labels[:, :, :, 0]
            #print('cnt:', cnt, 'predshape:',pred.shape， pred, 'labelshape:', labels.shape, labels)
            loss = criterion(pred, labels)
            print('val-cnt-%d-loss: %f' % (cnt, loss.item()), end='\r')
            sys.stdout.flush()
            tot += loss.item()
            cnt += 1
    return tot / cnt

# %%
#删除tensorboard中的log文件，避免出现显示错误
import os
print('deal with train loss file')
logfile_dir = "runs/UNet_train_log"
logfile_ids = os.listdir(logfile_dir)
logfile_fps = [os.path.join(logfile_dir, logfile_id) for logfile_id in logfile_ids]
for i in range(len(logfile_ids)):
    print('file %d : %s' % (i, logfile_fps[i]))
for i in range(len(logfile_ids)):
    print('try to deal with file: %s' % logfile_fps[i])
    if logfile_fps[i][-6:] == 'points' or logfile_fps[i][-6:] == '_train' or logfile_fps[i][-6:] == '_valid':
        print('do not delete file: %s' % logfile_fps[i])
        continue
    print('delete logfile: %s', logfile_fps[i])
    os.remove(logfile_fps[i])

print('\n deal with epoch_loss_train flie')
logfile_dir = "runs/UNet_train_log/epoch_loss_train"
logfile_ids = os.listdir(logfile_dir)
logfile_fps = [os.path.join(logfile_dir, logfile_id) for logfile_id in logfile_ids]
for i in range(len(logfile_ids)):
    print('file %d : %s' % (i, logfile_fps[i]))
for i in range(len(logfile_ids)):
    print('try to deal with file: %s' % logfile_fps[i])
    if logfile_fps[i][-6:] == 'points' or logfile_fps[i][-6:] == '_train' or logfile_fps[i][-6:] == '_valid':
        print('do not delete file: %s' % logfile_fps[i])
        continue
    print('delete logfile: %s', logfile_fps[i])
    os.remove(logfile_fps[i])

print('\n deal with epoch_loss_valid flie')
logfile_dir = "runs/UNet_train_log/epoch_loss_valid"
logfile_ids = os.listdir(logfile_dir)
logfile_fps = [os.path.join(logfile_dir, logfile_id) for logfile_id in logfile_ids]
for i in range(len(logfile_ids)):
    print('file %d : %s' % (i, logfile_fps[i]))
for i in range(len(logfile_ids)):
    print('try to deal with file: %s' % logfile_fps[i])
    if logfile_fps[i][-6:] == 'points' or logfile_fps[i][-6:] == '_train' or logfile_fps[i][-6:] == '_valid':
        print('do not delete file: %s' % logfile_fps[i])
        continue
    print('delete logfile: %s', logfile_fps[i])
    os.remove(logfile_fps[i])

print('\n deal with mIoU_train flie')
logfile_dir = "runs/UNet_train_log/mIoU_train"
logfile_ids = os.listdir(logfile_dir)
logfile_fps = [os.path.join(logfile_dir, logfile_id) for logfile_id in logfile_ids]
for i in range(len(logfile_ids)):
    print('file %d : %s' % (i, logfile_fps[i]))
for i in range(len(logfile_ids)):
    print('try to deal with file: %s' % logfile_fps[i])
    if logfile_fps[i][-6:] == 'points' or logfile_fps[i][-6:] == '_train' or logfile_fps[i][-6:] == '_valid':
        print('do not delete file: %s' % logfile_fps[i])
        continue
    print('delete logfile: %s', logfile_fps[i])
    os.remove(logfile_fps[i])
    
print('\n deal with mIoU_valid flie')
logfile_dir = "runs/UNet_train_log/mIoU_valid"
logfile_ids = os.listdir(logfile_dir)
logfile_fps = [os.path.join(logfile_dir, logfile_id) for logfile_id in logfile_ids]
for i in range(len(logfile_ids)):
    print('file %d : %s' % (i, logfile_fps[i]))
for i in range(len(logfile_ids)):
    print('try to deal with file: %s' % logfile_fps[i])
    if logfile_fps[i][-6:] == 'points' or logfile_fps[i][-6:] == '_train' or logfile_fps[i][-6:] == '_valid':
        print('do not delete file: %s' % logfile_fps[i])
        continue
    print('delete logfile: %s', logfile_fps[i])
    os.remove(logfile_fps[i])
# Out:
# deal with train loss file
# file 0 : runs/UNet_train_log\.ipynb_checkpoints
# file 1 : runs/UNet_train_log\epoch_loss_train
# file 2 : runs/UNet_train_log\epoch_loss_valid
# file 3 : runs/UNet_train_log\events.out.tfevents.1589583498.DESKTOP-96ILCK0.5448.0
# file 4 : runs/UNet_train_log\mIoU_train
# file 5 : runs/UNet_train_log\mIoU_valid
# try to deal with file: runs/UNet_train_log\.ipynb_checkpoints
# do not delete file: runs/UNet_train_log\.ipynb_checkpoints
# try to deal with file: runs/UNet_train_log\epoch_loss_train
# do not delete file: runs/UNet_train_log\epoch_loss_train
# try to deal with file: runs/UNet_train_log\epoch_loss_valid
# do not delete file: runs/UNet_train_log\epoch_loss_valid
# try to deal with file: runs/UNet_train_log\events.out.tfevents.1589583498.DESKTOP-96ILCK0.5448.0
# delete logfile: %s runs/UNet_train_log\events.out.tfevents.1589583498.DESKTOP-96ILCK0.5448.0
# try to deal with file: runs/UNet_train_log\mIoU_train
# do not delete file: runs/UNet_train_log\mIoU_train
# try to deal with file: runs/UNet_train_log\mIoU_valid
# do not delete file: runs/UNet_train_log\mIoU_valid
#
#  deal with epoch_loss_train flie
# file 0 : runs/UNet_train_log/epoch_loss_train\events.out.tfevents.1589583950.DESKTOP-96ILCK0.5448.1
# try to deal with file: runs/UNet_train_log/epoch_loss_train\events.out.tfevents.1589583950.DESKTOP-96ILCK0.5448.1
# delete logfile: %s runs/UNet_train_log/epoch_loss_train\events.out.tfevents.1589583950.DESKTOP-96ILCK0.5448.1
#
#  deal with epoch_loss_valid flie
# file 0 : runs/UNet_train_log/epoch_loss_valid\events.out.tfevents.1589583950.DESKTOP-96ILCK0.5448.2
# try to deal with file: runs/UNet_train_log/epoch_loss_valid\events.out.tfevents.1589583950.DESKTOP-96ILCK0.5448.2
# delete logfile: %s runs/UNet_train_log/epoch_loss_valid\events.out.tfevents.1589583950.DESKTOP-96ILCK0.5448.2
#
#  deal with mIoU_train flie
# file 0 : runs/UNet_train_log/mIoU_train\.ipynb_checkpoints
# file 1 : runs/UNet_train_log/mIoU_train\events.out.tfevents.1589584315.DESKTOP-96ILCK0.5448.4
# try to deal with file: runs/UNet_train_log/mIoU_train\.ipynb_checkpoints
# do not delete file: runs/UNet_train_log/mIoU_train\.ipynb_checkpoints
# try to deal with file: runs/UNet_train_log/mIoU_train\events.out.tfevents.1589584315.DESKTOP-96ILCK0.5448.4
# delete logfile: %s runs/UNet_train_log/mIoU_train\events.out.tfevents.1589584315.DESKTOP-96ILCK0.5448.4
#
#  deal with mIoU_valid flie
# file 0 : runs/UNet_train_log/mIoU_valid\.ipynb_checkpoints
# file 1 : runs/UNet_train_log/mIoU_valid\events.out.tfevents.1589584315.DESKTOP-96ILCK0.5448.3
# try to deal with file: runs/UNet_train_log/mIoU_valid\.ipynb_checkpoints
# do not delete file: runs/UNet_train_log/mIoU_valid\.ipynb_checkpoints
# try to deal with file: runs/UNet_train_log/mIoU_valid\events.out.tfevents.1589584315.DESKTOP-96ILCK0.5448.3
# delete logfile: %s runs/UNet_train_log/mIoU_valid\events.out.tfevents.1589584315.DESKTOP-96ILCK0.5448.3

# %%
#使用tensorboard对训练过程进行可视化
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter('runs/UNet_train_log')

# %%
x = torch.rand(2, 3, 360, 480)
with SummaryWriter(comment='DFANet') as w:
    w.add_graph(net, x.cuda())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\torch\jit\__init__.py:1044: TracerWarning: Output nr 1. of the traced function does not match the corresponding output of the Python function. Detailed error:
# Not within tolerance rtol=1e-05 atol=1e-05 at input[0, 3, 262, 48] (2.7819790840148926 vs. 2.783252477645874) and 431985 other locations (24.00%)
#   check_tolerance, _force_outplace, True, _module_class)

# %%
from torch.autograd import Variable
from torch import optim
import time

start_epoch = 0
resume = True #是否进行断点续训

optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9,weight_decay=0.00001)

#加载需要继续训练的模型以及参数
if resume:
    print('进行断点续训。')
    if os.path.isfile('DFA_model/checkpoint'):
        checkpoint = torch.load('DFA_model/checkpoint')
        start_epoch = checkpoint['epoch'] + 1
        net.load_state_dict(checkpoint['model'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        print("=> loaded checkpoint (epoch {})".format(checkpoint['epoch']))
    else:
        print("=> no checkpoint found")
else:
    print('进行初始训练。')

batch_size = 4
epochs1 = 1000 
write_log_num = 10
# best_loss统计，初始化为正无穷
train_best_loss = float('inf')
valid_best_loss = 0.
train_old_model = ''
train_new_model = ''
valid_old_model = ''
valid_new_model = ''
path_checkpoint = ''

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
miou_train_loader = DataLoader(train_dataset, batch_size=4, shuffle=False)
valid_loader = DataLoader(valid_dataset, batch_size=4, shuffle=False)
print('dataloader ready!')
train_sum = len(train_loader)
net.cuda()
#optimizer = optim.RMSprop(net.parameters(), lr=0.01, weight_decay=1e-8,  momentum=0.9)
#optimizer = optim.Adam(net.parameters(), lr=0.05, weight_decay=1e-8)
#scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=4)
def poly_lr_scheduler(epoch, num_epochs=epochs1, power=0.9):
    return (1 - epoch/num_epochs)**power

scheduler = optim.lr_scheduler.LambdaLR(optimizer=optimizer, lr_lambda=poly_lr_scheduler)

if net.n_classes > 1:
    criterion = nn.CrossEntropyLoss()
else:
    criterion = nn.BCELoss()

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('parameters set up!')
print('start to train!')
for epoch in range(start_epoch, epochs1):
    start = time.process_time()
    net.train()
    log_loss = 0 #每次进行tensorboard记录时的总loss
    epoch_loss = 0 #每一个epoch后的总loss
    cnt = 1
    
    for data in train_loader:
        optimizer.zero_grad()
        images,labels = data
        images = images.permute(0, 3, 1, 2)
        images = Variable(images.to(device=device, dtype=torch.float32))
        images = images/255.
        mask_type = torch.float32 if net.n_classes == 1 else torch.long
        labels = Variable(labels.to(device=device, dtype=mask_type))
        pred = net(images)
         
        if net.n_classes > 1:
            labels = torch.topk(labels, 1)[1].squeeze(1)
            labels = labels[:, :, :, 0]
            #print('cnt:', cnt, 'predshape:',pred.shape, 'labelshape:', labels.shape)
            loss = criterion(pred, labels)
        else:
            loss = criterion(pred, labels)
        epoch_loss += loss.item()
        loss.backward()
        optimizer.step() 
        print('epoch-%d-cnt-%d-loss: %f' % ( (epoch + 1), cnt, loss.item()), end='\r')
        sys.stdout.flush()
        cnt += 1
        '''if cnt > 10:
            break'''
    
    
    scheduler.step()   
    print('epoch-%d-epoch_avg_train_loss: %f' % ( (epoch + 1), epoch_loss / train_sum))
    #计算模型在验证集上的损失
    val_loss = eval_val_loss(net, valid_loader, device)

    print('epoch-%d-epoch_avg_val_loss: %f' % ( (epoch + 1), val_loss))
    writer.add_scalars('epoch_loss', {'train': epoch_loss / train_sum, 'valid': val_loss}, (epoch + 1))

    #保存在验证集上损失最低模型
    if val_loss < train_best_loss and val_loss < 0.4:
        train_best_loss = val_loss
        train_old_model = train_new_model
        train_new_model = 'DFA_model/train_epoch-' + str(epoch+1) + '-loss_valid-' + str(val_loss) + '.pth'
        torch.save(net.state_dict(), 'DFA_model/train_epoch-' + str(epoch+1) + '-loss_valid-' + str(val_loss) + '.pth')
        if train_old_model != '':
            print(train_old_model)
            os.remove(train_old_model)
    train_score = eval_net(net, miou_train_loader, device)
    print('avg_train_mIoU: %f' % train_score)
    #writer.add_scalar('train_mIoU', train_score, epoch + 1)
    val_score = eval_net(net, valid_loader, device)
    
    if val_score > valid_best_loss and val_score > 0.3:
      #保存最优mIoU的模型的参数，以便进行断点续训
        if path_checkpoint != '':
            os.remove(path_checkpoint)
        save_checkpoint = {
              'epoch': epoch,
              'model': net.state_dict(),
              'optimizer': optimizer.state_dict(),
          }
        torch.save(save_checkpoint, 'DFA_model/checkpoint')
        #保存最优模型
        path_checkpoint = 'DFA_model/checkpoint'
        valid_best_loss = val_score
        valid_old_model = valid_new_model
        valid_new_model = 'DFA_model/valid_epoch-' + str(epoch+1) + '-valid_mIoU-' + str(val_score) + '.pth'
        torch.save(net.state_dict(), 'DFA_model/valid_epoch-' + str(epoch+1) + '-valid_mIoU-' + str(val_score) + '.pth')
        if valid_old_model != '':
            print(valid_old_model)
            os.remove(valid_old_model)
    print('avg_val_mIoU: %f' % val_score)
    #scheduler.step(val_score)
    writer.add_scalars('mIoU', {'valid': val_score, 'train': train_score}, epoch + 1)
    writer.add_scalar('learning_rate', optimizer.param_groups[0]['lr'], epoch + 1)
    end = time.process_time()
    print('epoch %d cost time %f seconds' % ((epoch + 1, (end - start))))
# Out:
# 进行断点续训。
# => loaded checkpoint (epoch 610)
# dataloader ready!
# parameters set up!
# start to train!
# epoch-612-epoch_avg_train_loss: 0.237132
# epoch-612-epoch_avg_val_loss: 0.276994
# avg_train_mIoU: 0.658856
# avg_val_mIoU: 0.6440773
# epoch 612 cost time 1012.296875 seconds
# epoch-613-epoch_avg_train_loss: 0.242340
# epoch-613-epoch_avg_val_loss: 0.281075
# avg_train_mIoU: 0.661552
# DFA_model/valid_epoch-612-valid_mIoU-0.6440773709780641.pth
# avg_val_mIoU: 0.645274
# epoch 613 cost time 1035.390625 seconds
# epoch-614-epoch_avg_train_loss: 0.237687
# epoch-614-epoch_avg_val_loss: 0.281174
# avg_train_mIoU: 0.659719
# avg_val_mIoU: 0.6412305
# epoch 614 cost time 1037.515625 seconds
# epoch-615-epoch_avg_train_loss: 0.242515
# epoch-615-epoch_avg_val_loss: 0.282510
# avg_train_mIoU: 0.663360
# DFA_model/valid_epoch-613-valid_mIoU-0.6452736796604263.pth
# avg_val_mIoU: 0.646593
# epoch 615 cost time 1035.000000 seconds
# epoch-616-epoch_avg_train_loss: 0.238178
# epoch-616-epoch_avg_val_loss: 0.281329
# avg_train_mIoU: 0.663547
# avg_val_mIoU: 0.6458636
# epoch 616 cost time 1033.250000 seconds
# epoch-617-epoch_avg_train_loss: 0.238972
# epoch-617-epoch_avg_val_loss: 0.279169
# avg_train_mIoU: 0.661508
# avg_val_mIoU: 0.6452975
# epoch 617 cost time 1030.593750 seconds
# epoch-618-epoch_avg_train_loss: 0.233362
# epoch-618-epoch_avg_val_loss: 0.297189
# avg_train_mIoU: 0.653703
# avg_val_mIoU: 0.6357035
# epoch 618 cost time 1033.140625 seconds
# epoch-619-epoch_avg_train_loss: 0.235257
# epoch-619-epoch_avg_val_loss: 0.286294
# avg_train_mIoU: 0.665924
# avg_val_mIoU: 0.6436947
# epoch 619 cost time 1023.484375 seconds
# epoch-620-epoch_avg_train_loss: 0.233943
# epoch-620-epoch_avg_val_loss: 0.328129
# avg_train_mIoU: 0.651255
# avg_val_mIoU: 0.6207687
# epoch 620 cost time 1037.281250 seconds
# epoch-621-epoch_avg_train_loss: 0.243333
# epoch-621-epoch_avg_val_loss: 0.285516
# avg_train_mIoU: 0.662439
# avg_val_mIoU: 0.6385013
# epoch 621 cost time 1024.843750 seconds
# epoch-622-epoch_avg_train_loss: 0.237114
# epoch-622-epoch_avg_val_loss: 0.286853
# avg_train_mIoU: 0.666249
# avg_val_mIoU: 0.6441553
# epoch 622 cost time 1032.968750 seconds
# epoch-623-epoch_avg_train_loss: 0.235298
# epoch-623-epoch_avg_val_loss: 0.278427
# avg_train_mIoU: 0.661786
# avg_val_mIoU: 0.6454259
# epoch 623 cost time 1034.546875 seconds
# epoch-624-epoch_avg_train_loss: 0.239026
# epoch-624-epoch_avg_val_loss: 0.293793
# avg_train_mIoU: 0.647412
# avg_val_mIoU: 0.6374142
# epoch 624 cost time 1039.031250 seconds
# epoch-625-epoch_avg_train_loss: 0.232949
# epoch-625-epoch_avg_val_loss: 0.286446
# avg_train_mIoU: 0.665137
# avg_val_mIoU: 0.6417223
# epoch 625 cost time 1040.375000 seconds
# epoch-626-epoch_avg_train_loss: 0.231976
# epoch-626-epoch_avg_val_loss: 0.304604
# avg_train_mIoU: 0.659837
# avg_val_mIoU: 0.6349443
# epoch 626 cost time 1033.187500 seconds
# epoch-627-epoch_avg_train_loss: 0.231959
# epoch-627-epoch_avg_val_loss: 0.302743
# avg_train_mIoU: 0.659931
# avg_val_mIoU: 0.6330850
# epoch 627 cost time 1031.953125 seconds
# epoch-628-epoch_avg_train_loss: 0.231298
# epoch-628-epoch_avg_val_loss: 0.288748
# avg_train_mIoU: 0.663215
# avg_val_mIoU: 0.6417242
# epoch 628 cost time 1034.046875 seconds
# epoch-629-epoch_avg_train_loss: 0.233526
# epoch-629-epoch_avg_val_loss: 0.304058
# avg_train_mIoU: 0.659359
# avg_val_mIoU: 0.6329564
# epoch 629 cost time 1034.453125 seconds
# epoch-630-epoch_avg_train_loss: 0.241733
# epoch-630-epoch_avg_val_loss: 0.275715
# DFA_model/train_epoch-612-loss_valid-0.27699385831753415.pth
# avg_train_mIoU: 0.667533
# DFA_model/valid_epoch-615-valid_mIoU-0.6465925317671564.pth
# avg_val_mIoU: 0.648030
# epoch 630 cost time 1042.515625 seconds
# epoch-631-epoch_avg_train_loss: 0.236780
# epoch-631-epoch_avg_val_loss: 0.281822
# avg_train_mIoU: 0.667623
# DFA_model/valid_epoch-630-valid_mIoU-0.6480297531104751.pth
# avg_val_mIoU: 0.648600
# epoch 631 cost time 1040.546875 seconds
# epoch-632-epoch_avg_train_loss: 0.233589
# epoch-632-epoch_avg_val_loss: 0.289666
# avg_train_mIoU: 0.658826
# avg_val_mIoU: 0.6358688
# epoch 632 cost time 1040.015625 seconds
# epoch-633-epoch_avg_train_loss: 0.237344
# epoch-633-epoch_avg_val_loss: 0.290930
# avg_train_mIoU: 0.663726
# avg_val_mIoU: 0.6444854
# epoch 633 cost time 1041.390625 seconds
# epoch-634-epoch_avg_train_loss: 0.233017
# epoch-634-epoch_avg_val_loss: 0.283558
# avg_train_mIoU: 0.665024
# avg_val_mIoU: 0.6404929
# epoch 634 cost time 1042.921875 seconds
# epoch-635-epoch_avg_train_loss: 0.230767
# epoch-635-epoch_avg_val_loss: 0.288506
# avg_train_mIoU: 0.661942
# avg_val_mIoU: 0.6407975
# epoch 635 cost time 1039.203125 seconds
# epoch-636-epoch_avg_train_loss: 0.233338
# epoch-636-epoch_avg_val_loss: 0.278490
# avg_train_mIoU: 0.664379
# avg_val_mIoU: 0.6467892
# epoch 636 cost time 1034.484375 seconds
# epoch-637-epoch_avg_train_loss: 0.232145
# epoch-637-epoch_avg_val_loss: 0.279523
# avg_train_mIoU: 0.665469
# avg_val_mIoU: 0.6443965
# epoch 637 cost time 1032.078125 seconds
# epoch-638-epoch_avg_train_loss: 0.229284
# epoch-638-epoch_avg_val_loss: 0.284959
# avg_train_mIoU: 0.665353
# avg_val_mIoU: 0.6406477
# epoch 638 cost time 1033.968750 seconds
# epoch-639-epoch_avg_train_loss: 0.230543
# epoch-639-epoch_avg_val_loss: 0.277486
# avg_train_mIoU: 0.663258
# avg_val_mIoU: 0.6409730
# epoch 639 cost time 1037.078125 seconds
# epoch-640-epoch_avg_train_loss: 0.225174
# epoch-640-epoch_avg_val_loss: 0.278900
# avg_train_mIoU: 0.668085
# avg_val_mIoU: 0.6458706
# epoch 640 cost time 1044.078125 seconds
# epoch-641-epoch_avg_train_loss: 0.228488
# epoch-641-epoch_avg_val_loss: 0.304216
# avg_train_mIoU: 0.657651
# avg_val_mIoU: 0.6354812
# epoch 641 cost time 1037.546875 seconds
# epoch-642-epoch_avg_train_loss: 0.231688
# epoch-642-epoch_avg_val_loss: 0.286101
# avg_train_mIoU: 0.664939
# avg_val_mIoU: 0.6447941
# epoch 642 cost time 1031.187500 seconds
# epoch-643-epoch_avg_train_loss: 0.227948
# epoch-643-epoch_avg_val_loss: 0.278909
# avg_train_mIoU: 0.665990
# DFA_model/valid_epoch-631-valid_mIoU-0.6486004768974252.pth
# avg_val_mIoU: 0.650467
# epoch 643 cost time 1040.703125 seconds
# epoch-644-epoch_avg_train_loss: 0.227690
# epoch-644-epoch_avg_val_loss: 0.278929
# avg_train_mIoU: 0.669646
# avg_val_mIoU: 0.6477200
# epoch 644 cost time 1039.265625 seconds
# epoch-645-epoch_avg_train_loss: 0.229387
# epoch-645-epoch_avg_val_loss: 0.279403
# avg_train_mIoU: 0.668321
# avg_val_mIoU: 0.6453086
# epoch 645 cost time 1041.093750 seconds
# epoch-646-epoch_avg_train_loss: 0.228330
# epoch-646-epoch_avg_val_loss: 0.291593
# avg_train_mIoU: 0.663245
# avg_val_mIoU: 0.6380988
# epoch 646 cost time 1042.062500 seconds
# epoch-647-epoch_avg_train_loss: 0.231023
# epoch-647-epoch_avg_val_loss: 0.281661
# avg_train_mIoU: 0.664387
# avg_val_mIoU: 0.6438683
# epoch 647 cost time 1036.265625 seconds
# epoch-648-epoch_avg_train_loss: 0.227894
# epoch-648-epoch_avg_val_loss: 0.274813
# DFA_model/train_epoch-630-loss_valid-0.27571467786199516.pth
# avg_train_mIoU: 0.671456
# DFA_model/valid_epoch-643-valid_mIoU-0.6504669924163156.pth
# avg_val_mIoU: 0.652103
# epoch 648 cost time 1032.968750 seconds
# epoch-649-epoch_avg_train_loss: 0.233397
# epoch-649-epoch_avg_val_loss: 0.284942
# avg_train_mIoU: 0.664547
# avg_val_mIoU: 0.6413139
# epoch 649 cost time 1032.484375 seconds
# epoch-650-epoch_avg_train_loss: 0.229917
# epoch-650-epoch_avg_val_loss: 0.289600
# avg_train_mIoU: 0.667818
# avg_val_mIoU: 0.6443740
# epoch 650 cost time 1033.015625 seconds
# epoch-651-epoch_avg_train_loss: 0.228119
# epoch-651-epoch_avg_val_loss: 0.280258
# avg_train_mIoU: 0.674584
# avg_val_mIoU: 0.6478202
# epoch 651 cost time 1030.906250 seconds
# epoch-652-epoch_avg_train_loss: 0.231441
# epoch-652-epoch_avg_val_loss: 0.286889
# avg_train_mIoU: 0.664241
# avg_val_mIoU: 0.6423836
# epoch 652 cost time 1035.343750 seconds
# epoch-653-epoch_avg_train_loss: 0.230544
# epoch-653-epoch_avg_val_loss: 0.270969
# DFA_model/train_epoch-648-loss_valid-0.27481301894618404.pth
# avg_train_mIoU: 0.670172
# avg_val_mIoU: 0.6484211
# epoch 653 cost time 1032.828125 seconds
# epoch-654-epoch_avg_train_loss: 0.228048
# epoch-654-epoch_avg_val_loss: 0.285420
# avg_train_mIoU: 0.670056
# avg_val_mIoU: 0.6471133
# epoch 654 cost time 1037.328125 seconds
# epoch-655-epoch_avg_train_loss: 0.231595
# epoch-655-epoch_avg_val_loss: 0.282359
# avg_train_mIoU: 0.674881
# avg_val_mIoU: 0.6499462
# epoch 655 cost time 1046.234375 seconds
# epoch-656-epoch_avg_train_loss: 0.227845
# epoch-656-epoch_avg_val_loss: 0.274387
# avg_train_mIoU: 0.668158
# avg_val_mIoU: 0.6456249
# epoch 656 cost time 1025.921875 seconds
# epoch-657-epoch_avg_train_loss: 0.229886
# epoch-657-epoch_avg_val_loss: 0.276684
# avg_train_mIoU: 0.667222
# avg_val_mIoU: 0.6470074
# epoch 657 cost time 1023.968750 seconds
# epoch-658-epoch_avg_train_loss: 0.235694
# epoch-658-epoch_avg_val_loss: 0.287106
# avg_train_mIoU: 0.666137
# avg_val_mIoU: 0.6407041
# epoch 658 cost time 1032.234375 seconds
# epoch-659-epoch_avg_train_loss: 0.226289
# epoch-659-epoch_avg_val_loss: 0.282294
# avg_train_mIoU: 0.669507
# avg_val_mIoU: 0.6508648
# epoch 659 cost time 1030.812500 seconds
# epoch-660-epoch_avg_train_loss: 0.225971
# epoch-660-epoch_avg_val_loss: 0.279291
# avg_train_mIoU: 0.670447
# avg_val_mIoU: 0.6453560
# epoch 660 cost time 1031.437500 seconds
# epoch-661-epoch_avg_train_loss: 0.230113
# epoch-661-epoch_avg_val_loss: 0.277572
# avg_train_mIoU: 0.669129
# avg_val_mIoU: 0.6424357
# epoch 661 cost time 1030.875000 seconds
# epoch-662-epoch_avg_train_loss: 0.224828
# epoch-662-epoch_avg_val_loss: 0.291258
# avg_train_mIoU: 0.669729
# avg_val_mIoU: 0.6421265
# epoch 662 cost time 1025.218750 seconds
# epoch-663-epoch_avg_train_loss: 0.225300
# epoch-663-epoch_avg_val_loss: 0.283885
# avg_train_mIoU: 0.665124
# avg_val_mIoU: 0.6435527
# epoch 663 cost time 1033.625000 seconds
# epoch-664-epoch_avg_train_loss: 0.224370
# epoch-664-epoch_avg_val_loss: 0.274209
# avg_train_mIoU: 0.670184
# avg_val_mIoU: 0.6463442
# epoch 664 cost time 1030.156250 seconds
# epoch-665-epoch_avg_train_loss: 0.228394
# epoch-665-epoch_avg_val_loss: 0.291930
# avg_train_mIoU: 0.664915
# avg_val_mIoU: 0.6368917
# epoch 665 cost time 1020.031250 seconds
# epoch-666-epoch_avg_train_loss: 0.222909
# epoch-666-epoch_avg_val_loss: 0.280472
# avg_train_mIoU: 0.678506
# avg_val_mIoU: 0.6499230
# epoch 666 cost time 1036.546875 seconds
# epoch-667-epoch_avg_train_loss: 0.226427
# epoch-667-epoch_avg_val_loss: 0.284375
# avg_train_mIoU: 0.670656
# avg_val_mIoU: 0.6450625
# epoch 667 cost time 1031.406250 seconds
# epoch-668-epoch_avg_train_loss: 0.225933
# epoch-668-epoch_avg_val_loss: 0.296491
# avg_train_mIoU: 0.668031
# avg_val_mIoU: 0.6339274
# epoch 668 cost time 1028.093750 seconds
# epoch-669-epoch_avg_train_loss: 0.228461
# epoch-669-epoch_avg_val_loss: 0.292862
# avg_train_mIoU: 0.658390
# avg_val_mIoU: 0.6381141
# epoch 669 cost time 1029.546875 seconds
# epoch-670-epoch_avg_train_loss: 0.225262
# epoch-670-epoch_avg_val_loss: 0.298145
# avg_train_mIoU: 0.665143
# avg_val_mIoU: 0.6382628
# epoch 670 cost time 1031.093750 seconds
# epoch-671-epoch_avg_train_loss: 0.226575
# epoch-671-epoch_avg_val_loss: 0.299468
# avg_train_mIoU: 0.661614
# avg_val_mIoU: 0.6370864
# epoch 671 cost time 1030.531250 seconds
# epoch-672-epoch_avg_train_loss: 0.227197
# epoch-672-epoch_avg_val_loss: 0.274829
# avg_train_mIoU: 0.675620
# avg_val_mIoU: 0.6517247
# epoch 672 cost time 1034.968750 seconds
# epoch-673-epoch_avg_train_loss: 0.225794
# epoch-673-epoch_avg_val_loss: 0.275034
# avg_train_mIoU: 0.674183
# avg_val_mIoU: 0.6520702
# epoch 673 cost time 1042.812500 seconds
# epoch-674-epoch_avg_train_loss: 0.234749
# epoch-674-epoch_avg_val_loss: 0.285342
# avg_train_mIoU: 0.665301
# avg_val_mIoU: 0.6445864
# epoch 674 cost time 1030.343750 seconds
# epoch-675-epoch_avg_train_loss: 0.223817
# epoch-675-epoch_avg_val_loss: 0.297441
# avg_train_mIoU: 0.674085
# avg_val_mIoU: 0.6438052
# epoch 675 cost time 1028.953125 seconds
# epoch-676-epoch_avg_train_loss: 0.223935
# epoch-676-epoch_avg_val_loss: 0.275860
# avg_train_mIoU: 0.676921
# DFA_model/valid_epoch-648-valid_mIoU-0.6521028278188573.pth
# avg_val_mIoU: 0.653477
# epoch 676 cost time 1031.578125 seconds
# epoch-677-epoch_avg_train_loss: 0.225449
# epoch-677-epoch_avg_val_loss: 0.286961
# avg_train_mIoU: 0.664817
# avg_val_mIoU: 0.6448013
# epoch 677 cost time 1030.906250 seconds
# epoch-678-epoch_avg_train_loss: 0.226559
# epoch-678-epoch_avg_val_loss: 0.284546
# avg_train_mIoU: 0.668526
# avg_val_mIoU: 0.6440998
# epoch 678 cost time 1030.000000 seconds
# epoch-679-epoch_avg_train_loss: 0.221705
# epoch-679-epoch_avg_val_loss: 0.284215
# avg_train_mIoU: 0.670758
# avg_val_mIoU: 0.6438243
# epoch 679 cost time 1038.687500 seconds
# epoch-680-epoch_avg_train_loss: 0.223679
# epoch-680-epoch_avg_val_loss: 0.294132
# avg_train_mIoU: 0.670450
# avg_val_mIoU: 0.6446670
# epoch 680 cost time 1033.406250 seconds
# epoch-681-epoch_avg_train_loss: 0.220792
# epoch-681-epoch_avg_val_loss: 0.272721
# avg_train_mIoU: 0.673320
# avg_val_mIoU: 0.6494884
# epoch 681 cost time 1029.484375 seconds
# epoch-682-epoch_avg_train_loss: 0.222843
# epoch-682-epoch_avg_val_loss: 0.278630
# avg_train_mIoU: 0.666584
# avg_val_mIoU: 0.6422618
# epoch 682 cost time 1037.937500 seconds
# epoch-683-epoch_avg_train_loss: 0.221601
# epoch-683-epoch_avg_val_loss: 0.279250
# avg_train_mIoU: 0.675967
# avg_val_mIoU: 0.6473263
# epoch 683 cost time 1036.187500 seconds
# epoch-684-epoch_avg_train_loss: 0.223665
# epoch-684-epoch_avg_val_loss: 0.285557
# avg_train_mIoU: 0.674868
# avg_val_mIoU: 0.6453139
# epoch 684 cost time 1040.484375 seconds
# epoch-685-epoch_avg_train_loss: 0.220154
# epoch-685-epoch_avg_val_loss: 0.291624
# avg_train_mIoU: 0.665042
# avg_val_mIoU: 0.6403030
# epoch 685 cost time 1033.015625 seconds
# epoch-686-epoch_avg_train_loss: 0.224496
# epoch-686-epoch_avg_val_loss: 0.278593
# avg_train_mIoU: 0.669832
# avg_val_mIoU: 0.6445701
# epoch 686 cost time 1027.328125 seconds
# epoch-687-epoch_avg_train_loss: 0.221740
# epoch-687-epoch_avg_val_loss: 0.282581
# avg_train_mIoU: 0.675769
# avg_val_mIoU: 0.6470417
# epoch 687 cost time 1025.609375 seconds
# epoch-688-epoch_avg_train_loss: 0.221894
# epoch-688-epoch_avg_val_loss: 0.283091
# avg_train_mIoU: 0.675028
# avg_val_mIoU: 0.6457475
# epoch 688 cost time 1030.875000 seconds
# epoch-689-epoch_avg_train_loss: 0.220909
# epoch-689-epoch_avg_val_loss: 0.284388
# avg_train_mIoU: 0.671507
# avg_val_mIoU: 0.6432651
# epoch 689 cost time 1031.312500 seconds
# epoch-690-epoch_avg_train_loss: 0.230721
# epoch-690-epoch_avg_val_loss: 0.288476
# avg_train_mIoU: 0.669107
# avg_val_mIoU: 0.6423300
# epoch 690 cost time 1030.671875 seconds
# epoch-691-epoch_avg_train_loss: 0.222893
# epoch-691-epoch_avg_val_loss: 0.291283
# avg_train_mIoU: 0.670139
# avg_val_mIoU: 0.6392597
# epoch 691 cost time 1032.390625 seconds
# epoch-692-epoch_avg_train_loss: 0.224128
# epoch-692-epoch_avg_val_loss: 0.277256
# avg_train_mIoU: 0.673256
# avg_val_mIoU: 0.6464837
# epoch 692 cost time 1032.468750 seconds
# epoch-693-epoch_avg_train_loss: 0.223242
# epoch-693-epoch_avg_val_loss: 0.289016
# avg_train_mIoU: 0.673178
# avg_val_mIoU: 0.6442847
# epoch 693 cost time 1036.187500 seconds
# epoch-694-epoch_avg_train_loss: 0.225153
# epoch-694-epoch_avg_val_loss: 0.278553
# avg_train_mIoU: 0.677298
# avg_val_mIoU: 0.6518565
# epoch 694 cost time 1024.968750 seconds
# epoch-695-epoch_avg_train_loss: 0.224108
# epoch-695-epoch_avg_val_loss: 0.277709
# avg_train_mIoU: 0.673348
# avg_val_mIoU: 0.6472125
# epoch 695 cost time 1028.890625 seconds
# epoch-696-epoch_avg_train_loss: 0.225191
# epoch-696-epoch_avg_val_loss: 0.284284
# avg_train_mIoU: 0.676039
# avg_val_mIoU: 0.6431569
# epoch 696 cost time 1029.812500 seconds
# epoch-697-epoch_avg_train_loss: 0.218269
# epoch-697-epoch_avg_val_loss: 0.285323
# avg_train_mIoU: 0.676383
# avg_val_mIoU: 0.6451436
# epoch 697 cost time 1031.921875 seconds
# epoch-698-epoch_avg_train_loss: 0.218101
# epoch-698-epoch_avg_val_loss: 0.275126
# avg_train_mIoU: 0.675171
# avg_val_mIoU: 0.6491114
# epoch 698 cost time 1027.000000 seconds
# epoch-699-epoch_avg_train_loss: 0.223708
# epoch-699-epoch_avg_val_loss: 0.277636
# avg_train_mIoU: 0.679449
# avg_val_mIoU: 0.6528608
# epoch 699 cost time 1026.156250 seconds
# epoch-700-epoch_avg_train_loss: 0.218420
# epoch-700-epoch_avg_val_loss: 0.277253
# avg_train_mIoU: 0.673189
# avg_val_mIoU: 0.6449375
# epoch 700 cost time 1031.203125 seconds
# epoch-701-epoch_avg_train_loss: 0.215581
# epoch-701-epoch_avg_val_loss: 0.276809
# avg_train_mIoU: 0.672797
# avg_val_mIoU: 0.6459923
# epoch 701 cost time 1026.656250 seconds
# epoch-702-epoch_avg_train_loss: 0.221898
# epoch-702-epoch_avg_val_loss: 0.278285
# avg_train_mIoU: 0.675455
# avg_val_mIoU: 0.6514681
# epoch 702 cost time 1034.671875 seconds
# epoch-703-epoch_avg_train_loss: 0.222808
# epoch-703-epoch_avg_val_loss: 0.287933
# avg_train_mIoU: 0.673384
# avg_val_mIoU: 0.6431306
# epoch 703 cost time 1027.609375 seconds
# epoch-704-epoch_avg_train_loss: 0.219666
# epoch-704-epoch_avg_val_loss: 0.275400
# avg_train_mIoU: 0.677532
# avg_val_mIoU: 0.6498037
# epoch 704 cost time 1032.187500 seconds
# epoch-705-epoch_avg_train_loss: 0.215999
# epoch-705-epoch_avg_val_loss: 0.276837
# avg_train_mIoU: 0.673701
# avg_val_mIoU: 0.6494152
# epoch 705 cost time 1033.171875 seconds
# epoch-706-epoch_avg_train_loss: 0.221992
# epoch-706-epoch_avg_val_loss: 0.278227
# avg_train_mIoU: 0.678908
# avg_val_mIoU: 0.6484776
# epoch 706 cost time 1028.625000 seconds
# epoch-707-epoch_avg_train_loss: 0.217918
# epoch-707-epoch_avg_val_loss: 0.282776
# avg_train_mIoU: 0.676817
# avg_val_mIoU: 0.6453743
# epoch 707 cost time 1035.218750 seconds
# epoch-708-epoch_avg_train_loss: 0.218237
# epoch-708-epoch_avg_val_loss: 0.277879
# avg_train_mIoU: 0.681520
# avg_val_mIoU: 0.6516597
# epoch 708 cost time 1030.625000 seconds
# epoch-709-epoch_avg_train_loss: 0.219143
# epoch-709-epoch_avg_val_loss: 0.274743
# avg_train_mIoU: 0.674694
# avg_val_mIoU: 0.6502133
# epoch 709 cost time 1028.843750 seconds
# epoch-710-epoch_avg_train_loss: 0.217509
# epoch-710-epoch_avg_val_loss: 0.275099
# avg_train_mIoU: 0.675930
# avg_val_mIoU: 0.6491044
# epoch 710 cost time 1032.531250 seconds
# epoch-711-epoch_avg_train_loss: 0.222702
# epoch-711-epoch_avg_val_loss: 0.286165
# avg_train_mIoU: 0.673644
# avg_val_mIoU: 0.6426097
# epoch 711 cost time 1026.937500 seconds
# epoch-712-epoch_avg_train_loss: 0.222094
# epoch-712-epoch_avg_val_loss: 0.276333
# avg_train_mIoU: 0.677345
# avg_val_mIoU: 0.6488624
# epoch 712 cost time 1029.953125 seconds
# epoch-713-epoch_avg_train_loss: 0.227590
# epoch-713-epoch_avg_val_loss: 0.283324
# avg_train_mIoU: 0.672584
# avg_val_mIoU: 0.6474792
# epoch 713 cost time 1031.343750 seconds
# epoch-714-epoch_avg_train_loss: 0.218724
# epoch-714-epoch_avg_val_loss: 0.286772
# avg_train_mIoU: 0.670408
# avg_val_mIoU: 0.6404447
# epoch 714 cost time 1029.765625 seconds
# epoch-715-epoch_avg_train_loss: 0.217147
# epoch-715-epoch_avg_val_loss: 0.281116
# avg_train_mIoU: 0.678661
# avg_val_mIoU: 0.6484817
# epoch 715 cost time 1021.578125 seconds
# epoch-716-epoch_avg_train_loss: 0.217971
# epoch-716-epoch_avg_val_loss: 0.286972
# avg_train_mIoU: 0.677816
# avg_val_mIoU: 0.6471395
# epoch 716 cost time 1027.328125 seconds
# epoch-717-epoch_avg_train_loss: 0.220875
# epoch-717-epoch_avg_val_loss: 0.291212
# avg_train_mIoU: 0.669721
# avg_val_mIoU: 0.6407657
# epoch 717 cost time 1025.796875 seconds
# epoch-718-epoch_avg_train_loss: 0.217882
# epoch-718-epoch_avg_val_loss: 0.298634
# avg_train_mIoU: 0.673730
# avg_val_mIoU: 0.6410558
# epoch 718 cost time 1026.859375 seconds
# epoch-719-epoch_avg_train_loss: 0.218592
# epoch-719-epoch_avg_val_loss: 0.282267
# avg_train_mIoU: 0.676025
# avg_val_mIoU: 0.6471693
# epoch 719 cost time 1028.765625 seconds
# epoch-720-epoch_avg_train_loss: 0.217032
# epoch-720-epoch_avg_val_loss: 0.294152
# avg_train_mIoU: 0.675660
# avg_val_mIoU: 0.6460872
# epoch 720 cost time 1026.406250 seconds
# epoch-721-epoch_avg_train_loss: 0.216382
# epoch-721-epoch_avg_val_loss: 0.286040
# avg_train_mIoU: 0.680521
# avg_val_mIoU: 0.6477597
# epoch 721 cost time 1028.906250 seconds
# epoch-722-epoch_avg_train_loss: 0.218221
# epoch-722-epoch_avg_val_loss: 0.275924
# avg_train_mIoU: 0.676597
# avg_val_mIoU: 0.6502623
# epoch 722 cost time 1023.984375 seconds
# epoch-723-epoch_avg_train_loss: 0.216471
# epoch-723-epoch_avg_val_loss: 0.279063
# avg_train_mIoU: 0.680575
# avg_val_mIoU: 0.6531364
# epoch 723 cost time 1026.125000 seconds
# epoch-724-epoch_avg_train_loss: 0.217614
# epoch-724-epoch_avg_val_loss: 0.270386
# DFA_model/train_epoch-653-loss_valid-0.270969130926662.pth
# avg_train_mIoU: 0.679918
# DFA_model/valid_epoch-676-valid_mIoU-0.6534765660762787.pth
# avg_val_mIoU: 0.653617
# epoch 724 cost time 1027.328125 seconds
# epoch-725-epoch_avg_train_loss: 0.219845
# epoch-725-epoch_avg_val_loss: 0.293504
# avg_train_mIoU: 0.670727
# avg_val_mIoU: 0.6406861
# epoch 725 cost time 1028.250000 seconds
# epoch-726-epoch_avg_train_loss: 0.218675
# epoch-726-epoch_avg_val_loss: 0.289243
# avg_train_mIoU: 0.679819
# avg_val_mIoU: 0.6493011
# epoch 726 cost time 1026.859375 seconds
# epoch-727-epoch_avg_train_loss: 0.221352
# epoch-727-epoch_avg_val_loss: 0.272720
# avg_train_mIoU: 0.677419
# avg_val_mIoU: 0.6494057
# epoch 727 cost time 1024.562500 seconds
# epoch-728-epoch_avg_train_loss: 0.217871
# epoch-728-epoch_avg_val_loss: 0.288871
# avg_train_mIoU: 0.675634
# avg_val_mIoU: 0.6431599
# epoch 728 cost time 1022.890625 seconds
# epoch-729-epoch_avg_train_loss: 0.215218
# epoch-729-epoch_avg_val_loss: 0.277843
# avg_train_mIoU: 0.679392
# avg_val_mIoU: 0.6513983
# epoch 729 cost time 1023.812500 seconds
# epoch-730-epoch_avg_train_loss: 0.215371
# epoch-730-epoch_avg_val_loss: 0.282681
# avg_train_mIoU: 0.676869
# avg_val_mIoU: 0.6443795
# epoch 730 cost time 1024.609375 seconds
# epoch-731-epoch_avg_train_loss: 0.214267
# epoch-731-epoch_avg_val_loss: 0.273736
# avg_train_mIoU: 0.682902
# avg_val_mIoU: 0.6516813
# epoch 731 cost time 1024.031250 seconds
# epoch-732-epoch_avg_train_loss: 0.216299
# epoch-732-epoch_avg_val_loss: 0.281877
# avg_train_mIoU: 0.679292
# avg_val_mIoU: 0.6468899
# epoch 732 cost time 1023.593750 seconds
# epoch-733-epoch_avg_train_loss: 0.214714
# epoch-733-epoch_avg_val_loss: 0.267357
# DFA_model/train_epoch-724-loss_valid-0.270385997576846.pth
# avg_train_mIoU: 0.682850
# avg_val_mIoU: 0.6530522
# epoch 733 cost time 1025.046875 seconds
# epoch-734-epoch_avg_train_loss: 0.219415
# epoch-734-epoch_avg_val_loss: 0.280125
# avg_train_mIoU: 0.676654
# avg_val_mIoU: 0.6458083
# epoch 734 cost time 1018.453125 seconds
# epoch-735-epoch_avg_train_loss: 0.216098
# epoch-735-epoch_avg_val_loss: 0.279150
# avg_train_mIoU: 0.678320
# avg_val_mIoU: 0.6474980
# epoch 735 cost time 1019.515625 seconds
# epoch-736-cnt-15-loss: 0.219157

# %%
 # 测试
from torchvision import transforms
from PIL import Image
test_dataset = Dataset(
    x_train_dir, 
    y_train_dir,
    classes=CLASSES,
    augmentation=get_test_augmentation(),
    )
cnt = 0
# 选择设备，有cuda用cuda，没有就用cpu
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# 加载网络，图片单通道，分类为1。
net = DFANet(cfg.ENCODER_CHANNEL_CFG,decoder_channel=64,n_classes=n_classes)
# 将网络拷贝到deivce中
net.to(device=device)
# 加载模型参数
print('load model')
net.load_state_dict(torch.load('DFA_model/valid_epoch-856-valid_mIoU-0.6621256098151207.pth', map_location=device))
print('done')
# 测试模式
print('model test')
net.eval()
print('done')

for num in range(len(test_dataset)):
    image, mask = test_dataset[num]
    show_image = image
    
    with torch.no_grad():
        image = image/255.
        image = image.astype('float32')
        image = torch.from_numpy(image)
        image = image.permute(2,0,1)
        image = image.to()
        print('imageshape:', image.shape)

        pred = net(image.unsqueeze(0).cuda())
        '''if net.n_classes > 1:
            pred = F.softmax(pred, dim=1)
            
        pred = pred.cpu()
        if net.n_classes > 1:
            pred = pred.permute(2, 3, 1, 0)'''
        mask = torch.from_numpy(mask)
        mask = torch.topk(mask, 1)[1].squeeze(1)
        mask = mask[..., 0].cpu()
        
        pred = pred.permute(2, 3, 1, 0)
        pred = torch.topk(pred[..., 0], 1)[1].squeeze(1)
        pred = pred[..., 0].cpu()
        #pred = pred.permute(2, 0, 1).cpu()
    #print(len(pred), len(pred[0]), len(pred[0, 0]))
    #print('pred:',pred.shape, pred)
    #print('mask:',mask.shape, mask)
    visualize(image=show_image,GT=mask,Pred=pred)
    cnt += 1
    if cnt > 20:
        break
# Out:
# load model
# done
# model test
# done
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
# imageshape: torch.Size([3, 360, 480])
